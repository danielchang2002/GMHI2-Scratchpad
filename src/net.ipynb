# %%
import pandas as pd
import numpy as np
import config

# %%
import functions
X, y = functions.load_taxonomy(boolean=True) 
X
# Out:
#                                                s__Abiotrophia_defectiva  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                      False
#                 SAMD00036193                                      False
#                 SAMD00036194                                      False
#                 SAMD00036197                                      False
#                 SAMD00036204                                      False
# ...                                                                 ...
# N5              SRR5279310                                        False
#                 SRR5279311                                        False
#                 SRR5279312                                        False
#                 SRR5279313                                        False
# V1              rhb_ram_0040                                      False
#
#                                                s__Acidaminococcus_fermentans  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                           False
#                 SAMD00036193                                           False
#                 SAMD00036194                                           False
#                 SAMD00036197                                           False
#                 SAMD00036204                                           False
# ...                                                                      ...
# N5              SRR5279310                                             False
#                 SRR5279311                                             False
#                 SRR5279312                                             False
#                 SRR5279313                                             False
# V1              rhb_ram_0040                                           False
#
#                                                s__Acidaminococcus_intestini  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                          False
#                 SAMD00036193                                          False
#                 SAMD00036194                                          False
#                 SAMD00036197                                          False
#                 SAMD00036204                                          False
# ...                                                                     ...
# N5              SRR5279310                                            False
#                 SRR5279311                                            False
#                 SRR5279312                                            False
#                 SRR5279313                                            False
# V1              rhb_ram_0040                                          False
#
#                                                s__Actinomyces_graevenitzii  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                          True
#                 SAMD00036193                                          True
#                 SAMD00036194                                         False
#                 SAMD00036197                                          True
#                 SAMD00036204                                          True
# ...                                                                    ...
# N5              SRR5279310                                           False
#                 SRR5279311                                           False
#                 SRR5279312                                           False
#                 SRR5279313                                            True
# V1              rhb_ram_0040                                         False
#
#                                                s__Actinomyces_odontolyticus  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                           True
#                 SAMD00036193                                          False
#                 SAMD00036194                                          False
#                 SAMD00036197                                           True
#                 SAMD00036204                                           True
# ...                                                                     ...
# N5              SRR5279310                                            False
#                 SRR5279311                                            False
#                 SRR5279312                                            False
#                 SRR5279313                                            False
# V1              rhb_ram_0040                                          False
#
#                                                s__Actinomyces_oris  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                 False
#                 SAMD00036193                                 False
#                 SAMD00036194                                 False
#                 SAMD00036197                                 False
#                 SAMD00036204                                  True
# ...                                                            ...
# N5              SRR5279310                                   False
#                 SRR5279311                                   False
#                 SRR5279312                                   False
#                 SRR5279313                                   False
# V1              rhb_ram_0040                                 False
#
#                                                s__Actinomyces_turicensis  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                       False
#                 SAMD00036193                                       False
#                 SAMD00036194                                       False
#                 SAMD00036197                                       False
#                 SAMD00036204                                       False
# ...                                                                  ...
# N5              SRR5279310                                         False
#                 SRR5279311                                         False
#                 SRR5279312                                         False
#                 SRR5279313                                         False
# V1              rhb_ram_0040                                       False
#
#                                                s__Actinomyces_viscosus  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                     False
#                 SAMD00036193                                     False
#                 SAMD00036194                                     False
#                 SAMD00036197                                      True
#                 SAMD00036204                                     False
# ...                                                                ...
# N5              SRR5279310                                       False
#                 SRR5279311                                       False
#                 SRR5279312                                       False
#                 SRR5279313                                       False
# V1              rhb_ram_0040                                     False
#
#                                                s__Adlercreutzia_equolifaciens  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                            False
#                 SAMD00036193                                             True
#                 SAMD00036194                                             True
#                 SAMD00036197                                             True
#                 SAMD00036204                                             True
# ...                                                                       ...
# N5              SRR5279310                                              False
#                 SRR5279311                                              False
#                 SRR5279312                                              False
#                 SRR5279313                                              False
# V1              rhb_ram_0040                                            False
#
#                                                s__Aggregatibacter_segnis  ...  \
# Study Accession Sample Accession or Sample ID                             ...
# PRJDB3601       SAMD00036192                                       False  ...
#                 SAMD00036193                                       False  ...
#                 SAMD00036194                                       False  ...
#                 SAMD00036197                                       False  ...
#                 SAMD00036204                                       False  ...
# ...                                                                  ...  ...
# N5              SRR5279310                                         False  ...
#                 SRR5279311                                         False  ...
#                 SRR5279312                                         False  ...
#                 SRR5279313                                         False  ...
# V1              rhb_ram_0040                                       False  ...
#
#                                                s__Subdoligranulum_variabile  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                          False
#                 SAMD00036193                                          False
#                 SAMD00036194                                          False
#                 SAMD00036197                                          False
#                 SAMD00036204                                          False
# ...                                                                     ...
# N5              SRR5279310                                            False
#                 SRR5279311                                            False
#                 SRR5279312                                            False
#                 SRR5279313                                            False
# V1              rhb_ram_0040                                          False
#
#                                                s__Succinatimonas_hippei  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                      False
#                 SAMD00036193                                      False
#                 SAMD00036194                                      False
#                 SAMD00036197                                      False
#                 SAMD00036204                                      False
# ...                                                                 ...
# N5              SRR5279310                                        False
#                 SRR5279311                                        False
#                 SRR5279312                                        False
#                 SRR5279313                                        False
# V1              rhb_ram_0040                                      False
#
#                                                s__Sutterella_wadsworthensis  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                           True
#                 SAMD00036193                                           True
#                 SAMD00036194                                           True
#                 SAMD00036197                                           True
#                 SAMD00036204                                          False
# ...                                                                     ...
# N5              SRR5279310                                            False
#                 SRR5279311                                            False
#                 SRR5279312                                            False
#                 SRR5279313                                             True
# V1              rhb_ram_0040                                          False
#
#                                                s__Turicibacter_sanguinis  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                       False
#                 SAMD00036193                                       False
#                 SAMD00036194                                       False
#                 SAMD00036197                                       False
#                 SAMD00036204                                       False
# ...                                                                  ...
# N5              SRR5279310                                         False
#                 SRR5279311                                         False
#                 SRR5279312                                         False
#                 SRR5279313                                         False
# V1              rhb_ram_0040                                       False
#
#                                                s__Varibaculum_cambriense  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                       False
#                 SAMD00036193                                       False
#                 SAMD00036194                                       False
#                 SAMD00036197                                       False
#                 SAMD00036204                                       False
# ...                                                                  ...
# N5              SRR5279310                                         False
#                 SRR5279311                                         False
#                 SRR5279312                                         False
#                 SRR5279313                                         False
# V1              rhb_ram_0040                                       False
#
#                                                s__Veillonella_atypica  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                     True
#                 SAMD00036193                                    False
#                 SAMD00036194                                    False
#                 SAMD00036197                                     True
#                 SAMD00036204                                    False
# ...                                                               ...
# N5              SRR5279310                                      False
#                 SRR5279311                                      False
#                 SRR5279312                                      False
#                 SRR5279313                                       True
# V1              rhb_ram_0040                                    False
#
#                                                s__Veillonella_dispar  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                    True
#                 SAMD00036193                                   False
#                 SAMD00036194                                   False
#                 SAMD00036197                                    True
#                 SAMD00036204                                   False
# ...                                                              ...
# N5              SRR5279310                                     False
#                 SRR5279311                                     False
#                 SRR5279312                                     False
#                 SRR5279313                                      True
# V1              rhb_ram_0040                                   False
#
#                                                s__Veillonella_parvula  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                     True
#                 SAMD00036193                                    False
#                 SAMD00036194                                    False
#                 SAMD00036197                                     True
#                 SAMD00036204                                    False
# ...                                                               ...
# N5              SRR5279310                                      False
#                 SRR5279311                                      False
#                 SRR5279312                                      False
#                 SRR5279313                                       True
# V1              rhb_ram_0040                                    False
#
#                                                s__Weissella_cibaria  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                  False
#                 SAMD00036193                                  False
#                 SAMD00036194                                  False
#                 SAMD00036197                                  False
#                 SAMD00036204                                  False
# ...                                                             ...
# N5              SRR5279310                                    False
#                 SRR5279311                                    False
#                 SRR5279312                                    False
#                 SRR5279313                                    False
# V1              rhb_ram_0040                                  False
#
#                                                s__Weissella_confusa
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                  False
#                 SAMD00036193                                  False
#                 SAMD00036194                                  False
#                 SAMD00036197                                  False
#                 SAMD00036204                                  False
# ...                                                             ...
# N5              SRR5279310                                    False
#                 SRR5279311                                    False
#                 SRR5279312                                    False
#                 SRR5279313                                    False
# V1              rhb_ram_0040                                  False
#
# [5026 rows x 313 columns]

# %%
class Linear:
    def __init__(self, input_size, output_size):
        self.w = np.random.rand(output_size, input_size) / input_size
        self.b = np.random.rand(output_size, 1) / input_size
        
    def forward(self, X):
        """
        X = (n_i, m)
        """
        self.input = X
        return np.dot(self.w, X) + self.b
    
    def backward(self, grad):
        """
        grad is partial derivative of the cost function wrt the output of the linear layer.
        grad = (n_o, m)
        Returns partial derivative of the cost function wrt the input of the linear layer.
        """
#         print('backward linear')
        # (n_o, m) * (m, n_i) = (n_o, n_i)
        self.weight_grad = np.dot(grad, self.input.T)
        # (n_o, m)
        self.bias_grad = np.sum(grad, axis=1, keepdims=True)
        # (n_i, n_o) * (n_o, m) = (n_i, m)
        return np.dot(self.w.T, grad)
    
    def step(self, alpha):
        """
            Subtracts alpha * gradient from weights
        """
        self.w = self.w - alpha * self.weight_grad
        self.b = self.b - alpha * self.bias_grad

# %%
class Sigmoid:
    def __init__(self):
        pass
    
    def forward(self, z):
        # (n_i, m)
        self.output = 1 / (1 + np.exp(-1 * z)) 
        return self.output
    
    def backward(self, grad):
#         print('backward sigmoid')
        # (n_i, m) 
        return self.output * (1 - self.output) * grad

    def step(self, alpha):
        """Does nothing"""
        pass

# %%
class MSE:
    def __init__(self):
        pass
    
    def forward(self, y, y_hat):
        return np.square(y - y_hat)
    
    def backward(self, y, y_hat):
        """
            Returns partial derivative of cost function
            wrt y_hat
        """
        return -2 * (y - y_hat)

# %%
class Net:
    def __init__(self, layers):
        self.layers = layers
        self.mse = MSE()
        
    def forward(self, X):
        y_hat = X
        for layer in self.layers:
            y_hat = layer.forward(y_hat)
        return y_hat
    
    def backward(self, grad):
        """
            Grad is partial derivative of cost function wrt to y_hat
        """
        for layer in self.layers[::-1]:
            grad = layer.backward(grad)
            
    def step(self, alpha):
        for layer in self.layers:
            layer.step(alpha)
    
    def fit(self, X, y, epochs=30, mini_batch_size=10, alpha=0.03, test_data=None):
        y = pd.get_dummies(y[0, :]).T.values
        for epoch in range(epochs):
            for minibatch in self.get_minibatches(X, y, mini_batch_size):
                X_batch, y_batch = minibatch
                y_hat = self.forward(X_batch)
                grad = self.mse.backward(y_batch, y_hat)
                self.backward(grad)
                self.step(alpha)
            print("End epoch", str(epoch), )
            if test_data is not None:
                print("Accuracy:", self.score(test_data[0], test_data[1]))
                
    def predict(self, X):
        y_hat = self.forward(X)
        predictions = np.argmax(y_hat, axis=0)
        return predictions
        
    def score(self, X, y):
        """Returns accuracy"""
        predictions = self.predict(X)
        accuracy = (y == predictions).sum(axis=0).mean()
        return accuracy
    
    def get_minibatches(self, X, y, mini_batch_size):
        m = X.shape[1]
        perm = np.random.permutation(m)
        mini_batches = []
        for start_idx in range(0, m, mini_batch_size):
            end_idx = min(start_idx + mini_batch_size, m - 1)
            X_batch = X[:, start_idx:end_idx]
            y_batch = y[:, start_idx:end_idx]
            mini_batches.append((X_batch, y_batch))
        return mini_batches

# %%
species = list(X.columns)
genus = np.unique([s.split("_")[2] for s in species])

# %%
dfs = []
for g in genus:
    species_with_g = list(filter(lambda x : g in x, species))
    df = pd.DataFrame(X[species_with_g].sum(axis=1))
    df.columns = [g]
    dfs.append(df)
genus_df = pd.concat(dfs, axis=1)
genus_df
# Out:
#                                                Abiotrophia  Acidaminococcus  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                             0                0
#                 SAMD00036193                             0                0
#                 SAMD00036194                             0                0
#                 SAMD00036197                             0                0
#                 SAMD00036204                             0                0
# ...                                                    ...              ...
# N5              SRR5279310                               0                0
#                 SRR5279311                               0                0
#                 SRR5279312                               0                0
#                 SRR5279313                               0                0
# V1              rhb_ram_0040                             0                0
#
#                                                Actinomyces  Adlercreutzia  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                             2              0
#                 SAMD00036193                             1              1
#                 SAMD00036194                             0              1
#                 SAMD00036197                             3              1
#                 SAMD00036204                             3              1
# ...                                                    ...            ...
# N5              SRR5279310                               0              0
#                 SRR5279311                               0              0
#                 SRR5279312                               0              0
#                 SRR5279313                               1              0
# V1              rhb_ram_0040                             0              0
#
#                                                Aggregatibacter  Akkermansia  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                 0            0
#                 SAMD00036193                                 0            1
#                 SAMD00036194                                 0            1
#                 SAMD00036197                                 0            0
#                 SAMD00036204                                 0            1
# ...                                                        ...          ...
# N5              SRR5279310                                   0            0
#                 SRR5279311                                   0            0
#                 SRR5279312                                   0            0
#                 SRR5279313                                   0            0
# V1              rhb_ram_0040                                 0            1
#
#                                                Alistipes  Alloscardovia  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                           1              0
#                 SAMD00036193                           2              0
#                 SAMD00036194                           2              0
#                 SAMD00036197                           0              0
#                 SAMD00036204                           2              0
# ...                                                  ...            ...
# N5              SRR5279310                             5              0
#                 SRR5279311                             0              0
#                 SRR5279312                             0              0
#                 SRR5279313                             4              0
# V1              rhb_ram_0040                           1              0
#
#                                                Anaerococcus  Anaerofustis  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                              0             0
#                 SAMD00036193                              0             0
#                 SAMD00036194                              0             0
#                 SAMD00036197                              0             0
#                 SAMD00036204                              0             0
# ...                                                     ...           ...
# N5              SRR5279310                                0             0
#                 SRR5279311                                0             0
#                 SRR5279312                                0             0
#                 SRR5279313                                0             0
# V1              rhb_ram_0040                              0             0
#
#                                                ...  Staphylococcus  \
# Study Accession Sample Accession or Sample ID  ...
# PRJDB3601       SAMD00036192                   ...               0
#                 SAMD00036193                   ...               0
#                 SAMD00036194                   ...               0
#                 SAMD00036197                   ...               0
#                 SAMD00036204                   ...               0
# ...                                            ...             ...
# N5              SRR5279310                     ...               0
#                 SRR5279311                     ...               0
#                 SRR5279312                     ...               0
#                 SRR5279313                     ...               0
# V1              rhb_ram_0040                   ...               0
#
#                                                Streptococcus  Subdoligranulum  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                               9                0
#                 SAMD00036193                               4                0
#                 SAMD00036194                               7                0
#                 SAMD00036197                              10                0
#                 SAMD00036204                               3                0
# ...                                                      ...              ...
# N5              SRR5279310                                 0                0
#                 SRR5279311                                 0                0
#                 SRR5279312                                 1                1
#                 SRR5279313                                 7                0
# V1              rhb_ram_0040                               3                0
#
#                                                Succinatimonas  Sutterella  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                0           1
#                 SAMD00036193                                0           1
#                 SAMD00036194                                0           1
#                 SAMD00036197                                0           1
#                 SAMD00036204                                0           0
# ...                                                       ...         ...
# N5              SRR5279310                                  0           0
#                 SRR5279311                                  0           0
#                 SRR5279312                                  0           0
#                 SRR5279313                                  0           1
# V1              rhb_ram_0040                                0           0
#
#                                                Turicibacter  Varibaculum  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                              0            0
#                 SAMD00036193                              0            0
#                 SAMD00036194                              0            0
#                 SAMD00036197                              0            0
#                 SAMD00036204                              0            0
# ...                                                     ...          ...
# N5              SRR5279310                                0            0
#                 SRR5279311                                0            0
#                 SRR5279312                                0            0
#                 SRR5279313                                0            0
# V1              rhb_ram_0040                              0            0
#
#                                                Veillonella  Weissella  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                             3          0
#                 SAMD00036193                             0          0
#                 SAMD00036194                             0          0
#                 SAMD00036197                             3          0
#                 SAMD00036204                             0          0
# ...                                                    ...        ...
# N5              SRR5279310                               0          0
#                 SRR5279311                               0          0
#                 SRR5279312                               0          0
#                 SRR5279313                               3          0
# V1              rhb_ram_0040                             0          0
#
#                                                candidate
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                           0
#                 SAMD00036193                           0
#                 SAMD00036194                           0
#                 SAMD00036197                           0
#                 SAMD00036204                           0
# ...                                                  ...
# N5              SRR5279310                             0
#                 SRR5279311                             0
#                 SRR5279312                             0
#                 SRR5279313                             0
# V1              rhb_ram_0040                           0
#
# [5026 rows x 105 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
y_train.T.shape
# Out:
# (1, 4020)

# %%
net = Net([
    Linear(313, 30),
    Sigmoid(),
    Linear(30, 2),
    Sigmoid()
#     Linear(313, 2),
#     Sigmoid()
])
net.fit(X_train.T.values, y_train.T.values, test_data=(X_test.T.values, y_test.T.values), epochs=60)
# Out:
# End epoch 0
# Accuracy: 0.6978131212723658
# End epoch 1
# Accuracy: 0.731610337972167
# End epoch 2
# Accuracy: 0.742544731610338
# End epoch 3
# Accuracy: 0.7495029821073559
# End epoch 4
# Accuracy: 0.7534791252485089
# End epoch 5
# Accuracy: 0.7584493041749503
# End epoch 6
# Accuracy: 0.757455268389662
# End epoch 7
# Accuracy: 0.7564612326043738
# End epoch 8
# Accuracy: 0.757455268389662
# End epoch 9
# Accuracy: 0.7624254473161034
# End epoch 10
# Accuracy: 0.7624254473161034
# End epoch 11
# Accuracy: 0.76441351888668
# End epoch 12
# Accuracy: 0.7594433399602386
# End epoch 13
# Accuracy: 0.7544731610337972
# End epoch 14
# Accuracy: 0.7534791252485089
# End epoch 15
# Accuracy: 0.7514910536779325
# End epoch 16
# Accuracy: 0.7514910536779325
# End epoch 17
# Accuracy: 0.7504970178926441
# End epoch 18
# Accuracy: 0.7495029821073559
# End epoch 19
# Accuracy: 0.7495029821073559
# End epoch 20
# Accuracy: 0.7504970178926441
# End epoch 21
# Accuracy: 0.7475149105367793
# End epoch 22
# Accuracy: 0.7475149105367793
# End epoch 23
# Accuracy: 0.7435387673956262
# End epoch 24
# Accuracy: 0.7385685884691849
# End epoch 25
# Accuracy: 0.742544731610338
# End epoch 26
# Accuracy: 0.7435387673956262
# End epoch 27
# Accuracy: 0.7415506958250497
# End epoch 28
# Accuracy: 0.73558648111332
# End epoch 29
# Accuracy: 0.7335984095427436
# End epoch 30
# Accuracy: 0.731610337972167
# End epoch 31
# Accuracy: 0.7306163021868787
# End epoch 32
# Accuracy: 0.7306163021868787
# End epoch 33
# Accuracy: 0.7286282306163022
# End epoch 34
# Accuracy: 0.7276341948310139
# End epoch 35
# Accuracy: 0.7286282306163022
# End epoch 36
# Accuracy: 0.731610337972167
# End epoch 37
# Accuracy: 0.7326043737574552
# End epoch 38
# Accuracy: 0.7306163021868787
# End epoch 39
# Accuracy: 0.731610337972167
# End epoch 40
# Accuracy: 0.7335984095427436
# End epoch 41
# Accuracy: 0.7345924453280318
# End epoch 42
# Accuracy: 0.73558648111332
# End epoch 43
# Accuracy: 0.7365805168986084
# End epoch 44
# Accuracy: 0.7365805168986084
# End epoch 45
# Accuracy: 0.7375745526838966
# End epoch 46
# Accuracy: 0.7365805168986084
# End epoch 47
# Accuracy: 0.7385685884691849
# End epoch 48
# Accuracy: 0.7385685884691849
# End epoch 49
# Accuracy: 0.7395626242544732
# End epoch 50
# Accuracy: 0.7445328031809145
# End epoch 51
# Accuracy: 0.7395626242544732
# End epoch 52
# Accuracy: 0.7326043737574552
# End epoch 53
# Accuracy: 0.7326043737574552
# End epoch 54
# Accuracy: 0.7306163021868787
# End epoch 55
# Accuracy: 0.7296222664015904
# End epoch 56
# Accuracy: 0.7286282306163022
# End epoch 57
# Accuracy: 0.7266401590457257
# End epoch 58
# Accuracy: 0.7246520874751491
# End epoch 59
# Accuracy: 0.7236580516898609
