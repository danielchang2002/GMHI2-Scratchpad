# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import config

# %% [markdown]
# ## Read data

# %%
from functions import load_train
X_train, y_train = load_train()

# %%
from functions import load_val
X_val, y_val = load_val()

# %%
X = pd.concat([X_train, X_val])
y = pd.concat([y_train, y_val])
display(X)
display(y)
# Out:
#                                                s__Abiotrophia_defectiva  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                        0.0
#                 SAMD00036193                                        0.0
#                 SAMD00036194                                        0.0
#                 SAMD00036197                                        0.0
#                 SAMD00036204                                        0.0
# ...                                                                 ...
# N5              SRR5279310                                          0.0
#                 SRR5279311                                          0.0
#                 SRR5279312                                          0.0
#                 SRR5279313                                          0.0
# V1              rhb_ram_0040                                        0.0
#
#                                                s__Acidaminococcus_fermentans  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                             0.0
#                 SAMD00036193                                             0.0
#                 SAMD00036194                                             0.0
#                 SAMD00036197                                             0.0
#                 SAMD00036204                                             0.0
# ...                                                                      ...
# N5              SRR5279310                                               0.0
#                 SRR5279311                                               0.0
#                 SRR5279312                                               0.0
#                 SRR5279313                                               0.0
# V1              rhb_ram_0040                                             0.0
#
#                                                s__Acidaminococcus_intestini  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                            0.0
#                 SAMD00036193                                            0.0
#                 SAMD00036194                                            0.0
#                 SAMD00036197                                            0.0
#                 SAMD00036204                                            0.0
# ...                                                                     ...
# N5              SRR5279310                                              0.0
#                 SRR5279311                                              0.0
#                 SRR5279312                                              0.0
#                 SRR5279313                                              0.0
# V1              rhb_ram_0040                                            0.0
#
#                                                s__Actinomyces_graevenitzii  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                      0.003491
#                 SAMD00036193                                      0.000110
#                 SAMD00036194                                      0.000000
#                 SAMD00036197                                      0.000435
#                 SAMD00036204                                      0.001297
# ...                                                                    ...
# N5              SRR5279310                                        0.000000
#                 SRR5279311                                        0.000000
#                 SRR5279312                                        0.000000
#                 SRR5279313                                        0.000106
# V1              rhb_ram_0040                                      0.000000
#
#                                                s__Actinomyces_odontolyticus  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                       0.000377
#                 SAMD00036193                                       0.000000
#                 SAMD00036194                                       0.000000
#                 SAMD00036197                                       0.000014
#                 SAMD00036204                                       0.000028
# ...                                                                     ...
# N5              SRR5279310                                         0.000000
#                 SRR5279311                                         0.000000
#                 SRR5279312                                         0.000000
#                 SRR5279313                                         0.000000
# V1              rhb_ram_0040                                       0.000000
#
#                                                s__Actinomyces_oris  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                              0.000000
#                 SAMD00036193                              0.000000
#                 SAMD00036194                              0.000000
#                 SAMD00036197                              0.000000
#                 SAMD00036204                              0.000041
# ...                                                            ...
# N5              SRR5279310                                0.000000
#                 SRR5279311                                0.000000
#                 SRR5279312                                0.000000
#                 SRR5279313                                0.000000
# V1              rhb_ram_0040                              0.000000
#
#                                                s__Actinomyces_turicensis  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                         0.0
#                 SAMD00036193                                         0.0
#                 SAMD00036194                                         0.0
#                 SAMD00036197                                         0.0
#                 SAMD00036204                                         0.0
# ...                                                                  ...
# N5              SRR5279310                                           0.0
#                 SRR5279311                                           0.0
#                 SRR5279312                                           0.0
#                 SRR5279313                                           0.0
# V1              rhb_ram_0040                                         0.0
#
#                                                s__Actinomyces_viscosus  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                  0.000000
#                 SAMD00036193                                  0.000000
#                 SAMD00036194                                  0.000000
#                 SAMD00036197                                  0.000051
#                 SAMD00036204                                  0.000000
# ...                                                                ...
# N5              SRR5279310                                    0.000000
#                 SRR5279311                                    0.000000
#                 SRR5279312                                    0.000000
#                 SRR5279313                                    0.000000
# V1              rhb_ram_0040                                  0.000000
#
#                                                s__Adlercreutzia_equolifaciens  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                         0.000000
#                 SAMD00036193                                         0.000614
#                 SAMD00036194                                         0.001276
#                 SAMD00036197                                         0.000047
#                 SAMD00036204                                         0.001195
# ...                                                                       ...
# N5              SRR5279310                                           0.000000
#                 SRR5279311                                           0.000000
#                 SRR5279312                                           0.000000
#                 SRR5279313                                           0.000000
# V1              rhb_ram_0040                                         0.000000
#
#                                                s__Aggregatibacter_segnis  ...  \
# Study Accession Sample Accession or Sample ID                             ...
# PRJDB3601       SAMD00036192                                         0.0  ...
#                 SAMD00036193                                         0.0  ...
#                 SAMD00036194                                         0.0  ...
#                 SAMD00036197                                         0.0  ...
#                 SAMD00036204                                         0.0  ...
# ...                                                                  ...  ...
# N5              SRR5279310                                           0.0  ...
#                 SRR5279311                                           0.0  ...
#                 SRR5279312                                           0.0  ...
#                 SRR5279313                                           0.0  ...
# V1              rhb_ram_0040                                         0.0  ...
#
#                                                s__Subdoligranulum_variabile  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                            0.0
#                 SAMD00036193                                            0.0
#                 SAMD00036194                                            0.0
#                 SAMD00036197                                            0.0
#                 SAMD00036204                                            0.0
# ...                                                                     ...
# N5              SRR5279310                                              0.0
#                 SRR5279311                                              0.0
#                 SRR5279312                                              0.0
#                 SRR5279313                                              0.0
# V1              rhb_ram_0040                                            0.0
#
#                                                s__Succinatimonas_hippei  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                        0.0
#                 SAMD00036193                                        0.0
#                 SAMD00036194                                        0.0
#                 SAMD00036197                                        0.0
#                 SAMD00036204                                        0.0
# ...                                                                 ...
# N5              SRR5279310                                          0.0
#                 SRR5279311                                          0.0
#                 SRR5279312                                          0.0
#                 SRR5279313                                          0.0
# V1              rhb_ram_0040                                        0.0
#
#                                                s__Sutterella_wadsworthensis  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                       0.006551
#                 SAMD00036193                                       0.000183
#                 SAMD00036194                                       0.001943
#                 SAMD00036197                                       0.007306
#                 SAMD00036204                                       0.000000
# ...                                                                     ...
# N5              SRR5279310                                         0.000000
#                 SRR5279311                                         0.000000
#                 SRR5279312                                         0.000000
#                 SRR5279313                                         0.000804
# V1              rhb_ram_0040                                       0.000000
#
#                                                s__Turicibacter_sanguinis  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                         0.0
#                 SAMD00036193                                         0.0
#                 SAMD00036194                                         0.0
#                 SAMD00036197                                         0.0
#                 SAMD00036204                                         0.0
# ...                                                                  ...
# N5              SRR5279310                                           0.0
#                 SRR5279311                                           0.0
#                 SRR5279312                                           0.0
#                 SRR5279313                                           0.0
# V1              rhb_ram_0040                                         0.0
#
#                                                s__Varibaculum_cambriense  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                         0.0
#                 SAMD00036193                                         0.0
#                 SAMD00036194                                         0.0
#                 SAMD00036197                                         0.0
#                 SAMD00036204                                         0.0
# ...                                                                  ...
# N5              SRR5279310                                           0.0
#                 SRR5279311                                           0.0
#                 SRR5279312                                           0.0
#                 SRR5279313                                           0.0
# V1              rhb_ram_0040                                         0.0
#
#                                                s__Veillonella_atypica  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                 0.000979
#                 SAMD00036193                                 0.000000
#                 SAMD00036194                                 0.000000
#                 SAMD00036197                                 0.001900
#                 SAMD00036204                                 0.000000
# ...                                                               ...
# N5              SRR5279310                                   0.000000
#                 SRR5279311                                   0.000000
#                 SRR5279312                                   0.000000
#                 SRR5279313                                   0.000372
# V1              rhb_ram_0040                                 0.000000
#
#                                                s__Veillonella_dispar  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                0.000048
#                 SAMD00036193                                0.000000
#                 SAMD00036194                                0.000000
#                 SAMD00036197                                0.000175
#                 SAMD00036204                                0.000000
# ...                                                              ...
# N5              SRR5279310                                  0.000000
#                 SRR5279311                                  0.000000
#                 SRR5279312                                  0.000000
#                 SRR5279313                                  0.000296
# V1              rhb_ram_0040                                0.000000
#
#                                                s__Veillonella_parvula  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                 0.003579
#                 SAMD00036193                                 0.000000
#                 SAMD00036194                                 0.000000
#                 SAMD00036197                                 0.000812
#                 SAMD00036204                                 0.000000
# ...                                                               ...
# N5              SRR5279310                                   0.000000
#                 SRR5279311                                   0.000000
#                 SRR5279312                                   0.000000
#                 SRR5279313                                   0.000829
# V1              rhb_ram_0040                                 0.000000
#
#                                                s__Weissella_cibaria  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                    0.0
#                 SAMD00036193                                    0.0
#                 SAMD00036194                                    0.0
#                 SAMD00036197                                    0.0
#                 SAMD00036204                                    0.0
# ...                                                             ...
# N5              SRR5279310                                      0.0
#                 SRR5279311                                      0.0
#                 SRR5279312                                      0.0
#                 SRR5279313                                      0.0
# V1              rhb_ram_0040                                    0.0
#
#                                                s__Weissella_confusa
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                    0.0
#                 SAMD00036193                                    0.0
#                 SAMD00036194                                    0.0
#                 SAMD00036197                                    0.0
#                 SAMD00036204                                    0.0
# ...                                                             ...
# N5              SRR5279310                                      0.0
#                 SRR5279311                                      0.0
#                 SRR5279312                                      0.0
#                 SRR5279313                                      0.0
# V1              rhb_ram_0040                                    0.0
#
# [5026 rows x 313 columns]
#                                                Phenotype
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                        True
#                 SAMD00036193                        True
#                 SAMD00036194                       False
#                 SAMD00036197                        True
#                 SAMD00036204                        True
# ...                                                  ...
# N5              SRR5279310                         False
#                 SRR5279311                         False
#                 SRR5279312                         False
#                 SRR5279313                         False
# V1              rhb_ram_0040                       False
#
# [5026 rows x 1 columns]

# %% [markdown]
# ## Demo GMHI!!

# %%
import GMHI
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import accuracy_score
# import importlib
# importlib.reload(GMHI)

gmhi = GMHI.GMHI(use_shannon=False)
gmhi.fit(X, y)
gmhi.score(X, y)
# Out:
# 0.7200836874916894

# %%
gmhi.get_thetas()
# Out:
# (1.6, 0)
