# %% [markdown]
# ## Setup

# %%
import pandas as pd
import config
import numpy as np

# %% [markdown]
# ## Read Data

# %%
from functions import load_train, load_val
X_train, y_train = load_train(boolean=True)
X_val, y_val = load_val(boolean=True)
display(X_train.head())
display(y_train.head())
display(X_val.head())
display(y_val.head())
# Out:
# Species       s__Abiotrophia_defectiva  s__Acidaminococcus_fermentans  \
# SAMD00036192                         0                              0
# SAMD00036193                         0                              0
# SAMD00036194                         0                              0
# SAMD00036197                         0                              0
# SAMD00036204                         0                              0
#
# Species       s__Acidaminococcus_intestini  s__Actinomyces_graevenitzii  \
# SAMD00036192                             0                            1
# SAMD00036193                             0                            1
# SAMD00036194                             0                            0
# SAMD00036197                             0                            1
# SAMD00036204                             0                            1
#
# Species       s__Actinomyces_odontolyticus  s__Actinomyces_oris  \
# ...

# %%
# How sparse is X?
print(X_train.sum().sum() / (X_train.shape[0] * X_train.shape[1]))
print(X_val.sum().sum() / (X_val.shape[0] * X_val.shape[1]))
# Out:
# 0.2288177884788525
# 0.20169672559251295

# %% [markdown]
# ## Demo GHMI2!!!

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from GMHI2 import GMHI2

# Instantiate
model = GMHI2()

# Use 10 fold cv, shuffle data
kfold = KFold(10, shuffle=True, random_state=42)
bal_accs = cross_val_score(model, X_train, y_train, cv=kfold, scoring = "balanced_accuracy")
display(bal_accs, np.mean(bal_accs))
# Out:
# array([0.71848467, 0.68531423, 0.70156513, 0.68714077, 0.67626374,
#        0.69034406, 0.71530898, 0.72295947, 0.71900973, 0.69456352])
# 0.701095430707393

# %% [markdown]
# #### 10 fold cross validation on training set achieves 70.1% balanced accuracy

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import accuracy_score

model.fit(X_train, y_train)
y_val_hat = model.predict(X_val)
acc = accuracy_score(y_val_hat, y_val)
bal_acc = balanced_accuracy_score(y_val_hat, y_val)
acc, bal_acc
# Out:
# (0.6907216494845361, 0.6462680613420796)

# %% [markdown]
# #### 64.6% balanced accuracy on validation set
