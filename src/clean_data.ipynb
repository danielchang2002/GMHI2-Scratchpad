# %%
import functions

# %%
functions.clean1()
functions.clean2()
functions.clean3()
functions.clean4()
# Out:
# cleaning: Final_MetaCyc_pathways_4347.xlsx
# 	wrote to: ../data/clean/pathways4347.csv
# cleaning: Final_taxonomy_4347.xlsx
# 	wrote to: ../data/clean/taxonomy4347.csv
# 	wrote to: ../data/clean/isHealthy4347.csv
# cleaning: Vaidation_humann2.xlsx
# 	wrote to: ../data/clean/pathways241.csv
# 	wrote to: ../data/clean/isHealthy241.csv
# cleaning: Validation_final_679.csv
# 	wrote to: ../data/clean/taxonomy679.csv
# 	wrote to: ../data/clean/isHealthy679.csv

# %%
X, y = functions.load_taxonomy()
display(X)
display(y)
# Out:
#                                                s__Abiotrophia_defectiva  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                        0.0
#                 SAMD00036193                                        0.0
#                 SAMD00036194                                        0.0
#                 SAMD00036197                                        0.0
#                 SAMD00036204                                        0.0
# ...                                                                 ...
# N5              SRR5279310                                          0.0
#                 SRR5279311                                          0.0
#                 SRR5279312                                          0.0
#                 SRR5279313                                          0.0
# V1              rhb_ram_0040                                        0.0
#
# ...

# %%
X, y = functions.load_both()
display(X)
display(y)
# Out:
#                                                s__Abiotrophia_defectiva  \
# Study Accession Sample Accession or Sample ID
# PRJDB3601       SAMD00036192                                        0.0
#                 SAMD00036193                                        0.0
#                 SAMD00036194                                        0.0
#                 SAMD00036197                                        0.0
#                 SAMD00036204                                        0.0
# ...                                                                 ...
# L1              SAMEA2582183                                        0.0
#                 SAMEA2582184                                        0.0
#                 SAMEA2582185                                        0.0
#                 SAMEA2582186                                        0.0
# V1              rhb_ram_0040                                        0.0
#
# ...
