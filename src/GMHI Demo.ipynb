# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import config

# %% [markdown]
# ## Read data

# %%
from functions import load_train, load_val
X_train, y_train = load_train()
X_val, y_val = load_val()
display(X_train.head())
display(y_train.head())
display(X_val.head())
display(y_val.head())
# Out:
# Species       s__Abiotrophia_defectiva  s__Acidaminococcus_fermentans  \
# SAMD00036192                       0.0                            0.0
# SAMD00036193                       0.0                            0.0
# SAMD00036194                       0.0                            0.0
# SAMD00036197                       0.0                            0.0
# SAMD00036204                       0.0                            0.0
#
# Species       s__Acidaminococcus_intestini  s__Actinomyces_graevenitzii  \
# SAMD00036192                           0.0                     0.003491
# SAMD00036193                           0.0                     0.000110
# SAMD00036194                           0.0                     0.000000
# SAMD00036197                           0.0                     0.000435
# SAMD00036204                           0.0                     0.001297
#
# Species       s__Actinomyces_odontolyticus  s__Actinomyces_oris  \
# ...

# %% [markdown]
# ## Demo GMHI!!

# %%
from GMHI import GMHI
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import accuracy_score

gmhi = GMHI(use_shannon=False)
gmhi.fit(X_train, y_train)
y_train_hat = gmhi.predict(X_train)
score = balanced_accuracy_score(y_train, y_train_hat)
score
# Out:
# 0.7057284206717402

# %%
y_val_hat = gmhi.predict(X_val)
score = balanced_accuracy_score(y_val, y_val_hat)
score
# Out:
# 0.7628478201758362
