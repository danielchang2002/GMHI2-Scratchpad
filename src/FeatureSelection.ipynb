# %% [markdown]
# ## Setup

# %%
import pandas as pd
import config

# %%
thresh = 0.00001 # 1e-5
species = pd.read_csv(config.TRAIN_DIR + "taxonomy.csv", index_col = 0).T
# pathways = pd.read_csv(config.TRAIN_DIR + "pathways.csv", index_col = 0).T
X = (pd.concat([species], axis = 1) > thresh) * 1
# X = (pd.concat([species], axis = 1))
X.head()
# Out:
# Species       s__Abiotrophia_defectiva  s__Acidaminococcus_fermentans  \
# SAMD00036192                         0                              0
# SAMD00036193                         0                              0
# SAMD00036194                         0                              0
# SAMD00036197                         0                              0
# SAMD00036204                         0                              0
#
# Species       s__Acidaminococcus_intestini  s__Actinomyces_graevenitzii  \
# SAMD00036192                             0                            1
# SAMD00036193                             0                            1
# SAMD00036194                             0                            0
# SAMD00036197                             0                            1
# SAMD00036204                             0                            1
#
# Species       s__Actinomyces_odontolyticus  s__Actinomyces_oris  \
# ...

# %%
y = pd.read_csv(config.TRAIN_DIR + "isHealthy.csv", index_col=0).T
y.head()
# Out:
#               isHealthy
# SAMD00036192       True
# SAMD00036193       True
# SAMD00036194      False
# SAMD00036197       True
# SAMD00036204       True

# %%
from random import randint

def add_noise(df, n):
    """Adds or removes n 1s from each row"""
    df = df.copy()
    noise = np.zeros(df.shape, dtype=int)
    for row in range(df.shape[0]):
        for i in range(n):
            col = randint(0, df.shape[1] - 1)
            noise[row][col] = 1
    added = df + noise
    noised = np.where(added == 2, 0, added)
    return pd.DataFrame(noised, columns=df.columns, index=df.index)

# %%
seed(42)
factor = 10
X_dfs = [X] + [add_noise(X, 31) for i in range(factor - 1)]
X_dfs[3]
# Out:
# Species       s__Abiotrophia_defectiva  s__Acidaminococcus_fermentans  \
# SAMD00036192                         1                              0
# SAMD00036193                         0                              1
# SAMD00036194                         0                              0
# SAMD00036197                         0                              0
# SAMD00036204                         0                              0
# ...                                ...                            ...
# SAMN07534852                         0                              0
# SAMN07534870                         0                              0
# SAMN07534977                         0                              0
# SAMN07534978                         0                              0
# SAMN07535110                         0                              0
#
# Species       s__Acidaminococcus_intestini  s__Actinomyces_graevenitzii  \
# ...

# %%
X_aug = pd.concat(X_dfs)
X_aug
# Out:
# Species       s__Abiotrophia_defectiva  s__Acidaminococcus_fermentans  \
# SAMD00036192                         0                              0
# SAMD00036193                         0                              0
# SAMD00036194                         0                              0
# SAMD00036197                         0                              0
# SAMD00036204                         0                              0
# ...                                ...                            ...
# SAMN07534852                         0                              0
# SAMN07534870                         0                              0
# SAMN07534977                         1                              0
# SAMN07534978                         0                              0
# SAMN07535110                         0                              1
#
# Species       s__Acidaminococcus_intestini  s__Actinomyces_graevenitzii  \
# ...

# %%
y_dfs = [y for i in range(factor)]
y_aug = pd.concat(y_dfs)
y_aug
# Out:
#               isHealthy
# SAMD00036192       True
# SAMD00036193       True
# SAMD00036194      False
# SAMD00036197       True
# SAMD00036204       True
# ...                 ...
# SAMN07534852       True
# SAMN07534870       True
# SAMN07534977       True
# SAMN07534978       True
# SAMN07535110       True
#
# [43470 rows x 1 columns]

# %% [markdown]
# ## Use Lasso Regression to select features

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

import numpy as np

strat_kfold = StratifiedKFold(10, shuffle=True, random_state=42)

for C in [0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30, 100]:
    print(C)
    logreg = LogisticRegression(C=C, penalty='l1',
    fit_intercept=True, max_iter=700, random_state=42,
                        solver='saga', n_jobs=-1)
    scores = cross_val_score(logreg, X, np.ravel(y), cv = strat_kfold, 
                             scoring = "balanced_accuracy")
    print(scores, np.mean(scores))
# Out:
# 0.01
# [0.63682881 0.60881845 0.64098219 0.65955609 0.64374003 0.66919192
#  0.62543107 0.64691037 0.66183043 0.65641607] 0.6449705435194404
# 0.03
# [0.69873073 0.67002259 0.7114899  0.71767012 0.72388357 0.721458
#  0.69933239 0.71708581 0.67439353 0.69412759] 0.7028194227436156
# 0.1
# [0.73727406 0.71009436 0.75156167 0.73418394 0.75621345 0.74983386
#  0.7225882  0.75407467 0.69968648 0.72410113] 0.733961182735011
# 0.3
# [0.73435008 0.71335061 0.75345561 0.74278974 0.74674375 0.74398591
#  0.72191396 0.76474774 0.72132168 0.72044338] 0.7363102463310262
# 1
# [0.73727406 0.71421451 0.75156167 0.74880383 0.74674375 0.74122807
#  0.72314086 0.76123452 0.72146621 0.73213928] 0.737780676686491
# 3
# [0.73933413 0.71610845 0.74381978 0.74484981 0.74863769 0.73262228
#  0.73186179 0.77395326 0.71561826 0.71854224] 0.7365347691114081
# 10
# -------------------------------------------------------------------
# KeyboardInterrupt                 Traceback (most recent call last)
# ...

# %%
logreg = LogisticRegression(C=1, penalty='l1',
    fit_intercept=True, max_iter=1000, random_state=42,
                        solver='saga', n_jobs=-1)
logreg.fit(X, np.ravel(y))
logreg.coef_[0]
# Out:
# array([-8.89708474e-02, -2.26736534e-01, -2.98683900e-01,  0.00000000e+00,
#         6.22079210e-01, -1.42672323e-01,  3.21200259e-01,  5.03862418e-01,
#         0.00000000e+00, -3.56309568e-01, -7.32782783e-02,  3.16580950e-01,
#         1.13364643e-01,  6.28810964e-02, -2.46586529e-01,  3.15332214e-01,
#         4.05101458e-01,  3.06322285e-01,  3.29494142e-01, -2.52800773e-01,
#         0.00000000e+00,  0.00000000e+00, -3.74586457e-01, -1.80570576e-01,
#         0.00000000e+00,  1.21131274e-01,  2.23246113e-01, -2.64918109e-01,
#         1.20706333e+00,  0.00000000e+00,  3.46262955e-01, -4.37684268e-01,
#         1.01254958e-01,  2.29462540e-01, -2.29581787e-01, -9.10195345e-02,
#        -4.00770614e-01,  3.31130415e-01, -3.10529276e-02, -1.26368091e-01,
#        -2.17598758e-01,  7.53282388e-02,  1.98372344e-01, -5.61884226e-03,
#        -1.38068534e-01,  0.00000000e+00, -2.19203319e-01, -1.85330887e-01,
# ...

# %%
coef = pd.DataFrame(X.columns)
coef['coef'] = logreg.coef_[0]
coef
# Out:
#                            Species      coef
# 0         s__Abiotrophia_defectiva -0.088971
# 1    s__Acidaminococcus_fermentans -0.226737
# 2     s__Acidaminococcus_intestini -0.298684
# 3      s__Actinomyces_graevenitzii  0.000000
# 4     s__Actinomyces_odontolyticus  0.622079
# ..                             ...       ...
# 308         s__Veillonella_atypica -0.082974
# 309          s__Veillonella_dispar  0.000000
# 310         s__Veillonella_parvula -0.148521
# 311           s__Weissella_cibaria  0.043954
# 312           s__Weissella_confusa -0.052729
#
# [313 rows x 2 columns]

# %%
nonzero = coef[coef['coef'].abs() > 0.001]
nonzero
# Out:
#                            Species      coef
# 0         s__Abiotrophia_defectiva -0.088971
# 1    s__Acidaminococcus_fermentans -0.226737
# 2     s__Acidaminococcus_intestini -0.298684
# 4     s__Actinomyces_odontolyticus  0.622079
# 5              s__Actinomyces_oris -0.142672
# ..                             ...       ...
# 307      s__Varibaculum_cambriense  1.946751
# 308         s__Veillonella_atypica -0.082974
# 310         s__Veillonella_parvula -0.148521
# 311           s__Weissella_cibaria  0.043954
# 312           s__Weissella_confusa -0.052729
#
# [270 rows x 2 columns]

# %%
features = list(nonzero['Species'])
features
# Out:
# ['s__Acidaminococcus_fermentans',
#  's__Acidaminococcus_intestini',
#  's__Actinomyces_odontolyticus',
#  's__Actinomyces_turicensis',
#  's__Actinomyces_viscosus',
#  's__Aggregatibacter_segnis',
#  's__Akkermansia_muciniphila',
#  's__Alistipes_finegoldii',
#  's__Alistipes_indistinctus',
#  's__Alistipes_onderdonkii',
#  's__Alistipes_putredinis',
#  's__Alistipes_senegalensis',
#  's__Alistipes_shahii',
#  's__Alistipes_sp_AP11',
#  's__Alistipes_sp_HGB5',
#  's__Alloscardovia_omnicolens',
#  's__Anaerofustis_stercorihominis',
#  's__Anaeroglobus_geminatus',
#  's__Anaerostipes_hadrus',
#  's__Anaerotruncus_colihominis',
#  's__Atopobium_parvulum',
#  's__Atopobium_rimae',
#  's__Bacteroidales_bacterium_ph8',
#  's__Bacteroides_caccae',
#  's__Bacteroides_cellulosilyticus',
#  's__Bacteroides_clarus',
#  's__Bacteroides_coprocola',
#  's__Bacteroides_coprophilus',
#  's__Bacteroides_dorei',
#  's__Bacteroides_eggerthii',
#  's__Bacteroides_faecis',
# ...

# %%
with open(config.OUTPUT_DIR + "features.txt", 'w') as f:
    for feat in features:
        f.write(feat + "\n")

# %%
thresh = 0.00001 # 1e-5
species_val = pd.read_csv(config.VAL_DIR + "taxonomy679.csv", index_col = 0).T
X_val = (pd.concat([species_val], axis = 1) > thresh) * 1
X_val.head()
# Out:
#               s__Abiotrophia_defectiva  s__Acidaminococcus_fermentans  \
# RHB_RAM_0004                         0                              0
# RHB_RAM_0007                         0                              0
# RHB_RAM_0013                         0                              0
# RHB_RAM_0015                         0                              0
# RHB_RAM_0017                         0                              0
#
#               s__Acidaminococcus_intestini  s__Actinomyces_graevenitzii  \
# RHB_RAM_0004                             0                            0
# RHB_RAM_0007                             0                            0
# RHB_RAM_0013                             0                            0
# RHB_RAM_0015                             0                            0
# RHB_RAM_0017                             0                            0
#
#               s__Actinomyces_odontolyticus  s__Actinomyces_oris  \
# ...

# %%
y_val = pd.read_csv(config.VAL_DIR + "isHealthy679.csv", index_col=0)
print(y_val.sum())
y_val.head()
# Out:
# isHealthy    118
# dtype: int64
#               isHealthy
# Sample_ID
# RHB_RAM_0004      False
# RHB_RAM_0007      False
# RHB_RAM_0013      False
# RHB_RAM_0015      False
# RHB_RAM_0017      False

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import accuracy_score

y_hat_val = logreg.predict(X_val)
acc = accuracy_score(y_hat_val, y_val)
bal_acc = balanced_accuracy_score(y_hat_val, y_val)
bal_acc, acc
# Out:
# (0.6086418788730927, 0.6023564064801178)
