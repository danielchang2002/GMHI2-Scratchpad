# %% [markdown]
# ## Setup

# %%
import pandas as pd
data_dir = "../data/"
output_dir = "../output/"

# %%
thresh = 0.00001 # 1e-5
species = pd.read_csv(data_dir + "taxonomy.csv", index_col = 0).T
pathways = pd.read_csv(data_dir + "pathways.csv", index_col = 0).T
X = (pd.concat([species, pathways], axis = 1) > thresh) * 1
X.head()
# Out:
#               s__Abiotrophia_defectiva  s__Acidaminococcus_fermentans  \
# SAMD00036192                         0                              0
# SAMD00036193                         0                              0
# SAMD00036194                         0                              0
# SAMD00036197                         0                              0
# SAMD00036204                         0                              0
#
#               s__Acidaminococcus_intestini  s__Actinomyces_graevenitzii  \
# SAMD00036192                             0                            1
# SAMD00036193                             0                            1
# SAMD00036194                             0                            0
# SAMD00036197                             0                            1
# SAMD00036204                             0                            1
#
#               s__Actinomyces_odontolyticus  s__Actinomyces_oris  \
# SAMD00036192                             1                    0
# SAMD00036193                             0                    0
# SAMD00036194                             0                    0
# SAMD00036197                             1                    0
# SAMD00036204                             1                    1
#
#               s__Actinomyces_turicensis  s__Actinomyces_viscosus  \
# SAMD00036192                          0                        0
# SAMD00036193                          0                        0
# SAMD00036194                          0                        0
# SAMD00036197                          0                        1
# SAMD00036204                          0                        0
#
#               s__Adlercreutzia_equolifaciens  s__Aggregatibacter_segnis  ...  \
# SAMD00036192                               0                          0  ...
# SAMD00036193                               1                          0  ...
# SAMD00036194                               1                          0  ...
# SAMD00036197                               1                          0  ...
# SAMD00036204                               1                          0  ...
#
#               TRNA-CHARGING-PWY: tRNA charging  \
# SAMD00036192                                 1
# SAMD00036193                                 1
# SAMD00036194                                 1
# SAMD00036197                                 1
# SAMD00036204                                 1
#
#               TRPSYN-PWY: L-tryptophan biosynthesis  \
# SAMD00036192                                      1
# SAMD00036193                                      1
# SAMD00036194                                      1
# SAMD00036197                                      1
# SAMD00036204                                      1
#
#               TYRFUMCAT-PWY: L-tyrosine degradation I  \
# SAMD00036192                                        0
# SAMD00036193                                        0
# SAMD00036194                                        0
# SAMD00036197                                        0
# SAMD00036204                                        0
#
#               UBISYN-PWY: superpathway of ubiquinol-8 biosynthesis (prokaryotic)  \
# SAMD00036192                                                  1
# SAMD00036193                                                  0
# SAMD00036194                                                  0
# SAMD00036197                                                  0
# SAMD00036204                                                  1
#
#               UDPNACETYLGALSYN-PWY: UDP-N-acetyl-D-glucosamine biosynthesis II  \
# SAMD00036192                                                  0
# SAMD00036193                                                  0
# SAMD00036194                                                  0
# SAMD00036197                                                  0
# SAMD00036204                                                  0
#
#               UDPNAGSYN-PWY: UDP-N-acetyl-D-glucosamine biosynthesis I  \
# SAMD00036192                                                  1
# SAMD00036193                                                  1
# SAMD00036194                                                  1
# SAMD00036197                                                  1
# SAMD00036204                                                  1
#
#               URDEGR-PWY: superpathway of allantoin degradation in plants  \
# SAMD00036192                                                  0
# SAMD00036193                                                  0
# SAMD00036194                                                  0
# SAMD00036197                                                  0
# SAMD00036204                                                  1
#
#               URSIN-PWY: ureide biosynthesis  \
# SAMD00036192                               0
# SAMD00036193                               0
# SAMD00036194                               0
# SAMD00036197                               0
# SAMD00036204                               0
#
#               VALDEG-PWY: L-valine degradation I  \
# SAMD00036192                                   0
# SAMD00036193                                   0
# SAMD00036194                                   0
# SAMD00036197                                   0
# SAMD00036204                                   0
#
#               VALSYN-PWY: L-valine biosynthesis
# SAMD00036192                                  1
# SAMD00036193                                  1
# SAMD00036194                                  1
# SAMD00036197                                  1
# SAMD00036204                                  1
#
# [5 rows x 844 columns]

# %%
y = pd.read_csv(data_dir + "isHealthy.csv", index_col=0).T
y.head()
# Out:
#               isHealthy
# SAMD00036192       True
# SAMD00036193       True
# SAMD00036194      False
# SAMD00036197       True
# SAMD00036204       True

# %% [markdown]
# ## Use Lasso Regression to select features

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np

logreg = LogisticRegression(C=0.1, penalty='l1',
fit_intercept=False, max_iter=500, random_state=42,
                    solver='saga', n_jobs=-1)
clf = logreg.fit(X, np.ravel(y))

# %%
coefficients = pd.DataFrame(X.columns, columns=['feature'])
coefficients['coef'] = clf.coef_[0]
coefficients.head()
# Out:
#                          feature      coef
# 0       s__Abiotrophia_defectiva  0.000000
# 1  s__Acidaminococcus_fermentans -0.113528
# 2   s__Acidaminococcus_intestini -0.099617
# 3    s__Actinomyces_graevenitzii  0.000000
# 4   s__Actinomyces_odontolyticus  0.252240

# %%
div = 0.0001
pivot = pd.concat([X[y['isHealthy']].mean(), X[~y['isHealthy']].mean()], axis = 1)
pivot.columns = ['healthy', 'not']
pivot['diff'] = pivot['healthy'] - pivot['not']
pivot['foldh'] = (pivot['healthy'] + div) / (pivot['not'] + div)
pivot['foldn'] = (pivot['not'] + div) / (pivot['healthy'] + div)
pivot['weight'] = 0
pivot.loc[pivot['diff'] > 0, 'weight'] = np.log(pivot[pivot['diff'] > 0]['foldh'])
pivot.loc[pivot['diff'] < 0, 'weight'] = np.log(pivot[pivot['diff'] < 0]['foldn'])
pivot['weight2'] = (pivot['weight'] * pivot['diff'])
pivot
# Out:
#                                                      healthy       not  \
# s__Abiotrophia_defectiva                            0.006829  0.049679
# s__Acidaminococcus_fermentans                       0.040212  0.078317
# s__Acidaminococcus_intestini                        0.080046  0.115722
# s__Actinomyces_graevenitzii                         0.045144  0.122735
# s__Actinomyces_odontolyticus                        0.089909  0.155465
# ...                                                      ...       ...
# UDPNAGSYN-PWY: UDP-N-acetyl-D-glucosamine biosy...  0.991275  0.990064
# URDEGR-PWY: superpathway of allantoin degradati...  0.295903  0.443016
# URSIN-PWY: ureide biosynthesis                      0.003414  0.004091
# VALDEG-PWY: L-valine degradation I                  0.006449  0.003507
# VALSYN-PWY: L-valine biosynthesis                   1.000000  1.000000
#
#                                                         diff     foldh  \
# s__Abiotrophia_defectiva                           -0.042850  0.139187
# s__Acidaminococcus_fermentans                      -0.038104  0.514079
# s__Acidaminococcus_intestini                       -0.035676  0.691973
# s__Actinomyces_graevenitzii                        -0.077591  0.368332
# s__Actinomyces_odontolyticus                       -0.065556  0.578595
# ...                                                      ...       ...
# UDPNAGSYN-PWY: UDP-N-acetyl-D-glucosamine biosy...  0.001210  1.001222
# URDEGR-PWY: superpathway of allantoin degradati... -0.147113  0.668003
# URSIN-PWY: ureide biosynthesis                     -0.000677  0.838491
# VALDEG-PWY: L-valine degradation I                  0.002942  1.815822
# VALSYN-PWY: L-valine biosynthesis                   0.000000  1.000000
#
#                                                        foldn    weight  \
# s__Abiotrophia_defectiva                            7.184578  1.971937
# s__Acidaminococcus_fermentans                       1.945225  0.665378
# s__Acidaminococcus_intestini                        1.445144  0.368209
# s__Actinomyces_graevenitzii                         2.714942  0.998770
# s__Actinomyces_odontolyticus                        1.728324  0.547152
# ...                                                      ...       ...
# UDPNAGSYN-PWY: UDP-N-acetyl-D-glucosamine biosy...  0.998779  0.001222
# URDEGR-PWY: superpathway of allantoin degradati...  1.496998  0.403462
# URSIN-PWY: ureide biosynthesis                      1.192618  0.176151
# VALDEG-PWY: L-valine degradation I                  0.550715  0.596539
# VALSYN-PWY: L-valine biosynthesis                   1.000000  0.000000
#
#                                                      weight2
# s__Abiotrophia_defectiva                           -0.084498
# s__Acidaminococcus_fermentans                      -0.025354
# s__Acidaminococcus_intestini                       -0.013136
# s__Actinomyces_graevenitzii                        -0.077496
# s__Actinomyces_odontolyticus                       -0.035869
# ...                                                      ...
# UDPNAGSYN-PWY: UDP-N-acetyl-D-glucosamine biosy...  0.000001
# URDEGR-PWY: superpathway of allantoin degradati... -0.059354
# URSIN-PWY: ureide biosynthesis                     -0.000119
# VALDEG-PWY: L-valine degradation I                  0.001755
# VALSYN-PWY: L-valine biosynthesis                   0.000000
#
# [844 rows x 7 columns]

# %%
coefficients.index = coefficients['feature']
del coefficients['feature']
coefficients
# Out:
#                                                         coef
# feature
# s__Abiotrophia_defectiva                            0.000000
# s__Acidaminococcus_fermentans                      -0.113528
# s__Acidaminococcus_intestini                       -0.099617
# s__Actinomyces_graevenitzii                         0.000000
# s__Actinomyces_odontolyticus                        0.252240
# ...                                                      ...
# UDPNAGSYN-PWY: UDP-N-acetyl-D-glucosamine biosy...  0.000000
# URDEGR-PWY: superpathway of allantoin degradati...  0.000000
# URSIN-PWY: ureide biosynthesis                      0.000000
# VALDEG-PWY: L-valine degradation I                  0.000000
# VALSYN-PWY: L-valine biosynthesis                   0.000000
#
# [844 rows x 1 columns]

# %%
coefficients['weight2'] = pivot['weight2']
coefficients
# Out:
#                                                         coef   weight2
# feature
# s__Abiotrophia_defectiva                            0.000000 -0.084498
# s__Acidaminococcus_fermentans                      -0.113528 -0.025354
# s__Acidaminococcus_intestini                       -0.099617 -0.013136
# s__Actinomyces_graevenitzii                         0.000000 -0.077496
# s__Actinomyces_odontolyticus                        0.252240 -0.035869
# ...                                                      ...       ...
# UDPNAGSYN-PWY: UDP-N-acetyl-D-glucosamine biosy...  0.000000  0.000001
# URDEGR-PWY: superpathway of allantoin degradati...  0.000000 -0.059354
# URSIN-PWY: ureide biosynthesis                      0.000000 -0.000119
# VALDEG-PWY: L-valine degradation I                  0.000000  0.001755
# VALSYN-PWY: L-valine biosynthesis                   0.000000  0.000000
#
# [844 rows x 2 columns]

# %%
coefficients['abscoef'] = abs(coefficients['coef'])
coefficients
# Out:
#                                                         coef   weight2  \
# feature
# s__Abiotrophia_defectiva                            0.000000 -0.084498
# s__Acidaminococcus_fermentans                      -0.113528 -0.025354
# s__Acidaminococcus_intestini                       -0.099617 -0.013136
# s__Actinomyces_graevenitzii                         0.000000 -0.077496
# s__Actinomyces_odontolyticus                        0.252240 -0.035869
# ...                                                      ...       ...
# UDPNAGSYN-PWY: UDP-N-acetyl-D-glucosamine biosy...  0.000000  0.000001
# URDEGR-PWY: superpathway of allantoin degradati...  0.000000 -0.059354
# URSIN-PWY: ureide biosynthesis                      0.000000 -0.000119
# VALDEG-PWY: L-valine degradation I                  0.000000  0.001755
# VALSYN-PWY: L-valine biosynthesis                   0.000000  0.000000
#
#                                                      abscoef
# feature
# s__Abiotrophia_defectiva                            0.000000
# s__Acidaminococcus_fermentans                       0.113528
# s__Acidaminococcus_intestini                        0.099617
# s__Actinomyces_graevenitzii                         0.000000
# s__Actinomyces_odontolyticus                        0.252240
# ...                                                      ...
# UDPNAGSYN-PWY: UDP-N-acetyl-D-glucosamine biosy...  0.000000
# URDEGR-PWY: superpathway of allantoin degradati...  0.000000
# URSIN-PWY: ureide biosynthesis                      0.000000
# VALDEG-PWY: L-valine degradation I                  0.000000
# VALSYN-PWY: L-valine biosynthesis                   0.000000
#
# [844 rows x 3 columns]

# %%
sorted_df = coefficients.sort_values('abscoef', ascending=False)
sorted_df
# Out:
#                                                         coef   weight2  \
# feature
# s__Bifidobacterium_angulatum                        0.642635  0.213397
# s__Peptostreptococcus_stomatis                     -0.618613 -0.235289
# s__Solobacterium_moorei                            -0.614407 -0.364616
# s__Lactobacillus_acidophilus                        0.516800  0.049587
# s__Clostridium_bolteae                             -0.501387 -0.248070
# ...                                                      ...       ...
# FERMENTATION-PWY: mixed acid fermentation           0.000000 -0.003179
# FOLSYN-PWY: superpathway of tetrahydrofolate bi...  0.000000 -0.001264
# FUCCAT-PWY: fucose degradation                      0.000000 -0.000169
# GALACT-GLUCUROCAT-PWY: superpathway of hexuroni...  0.000000  0.000003
# VALSYN-PWY: L-valine biosynthesis                   0.000000  0.000000
#
#                                                      abscoef
# feature
# s__Bifidobacterium_angulatum                        0.642635
# s__Peptostreptococcus_stomatis                      0.618613
# s__Solobacterium_moorei                             0.614407
# s__Lactobacillus_acidophilus                        0.516800
# s__Clostridium_bolteae                              0.501387
# ...                                                      ...
# FERMENTATION-PWY: mixed acid fermentation           0.000000
# FOLSYN-PWY: superpathway of tetrahydrofolate bi...  0.000000
# FUCCAT-PWY: fucose degradation                      0.000000
# GALACT-GLUCUROCAT-PWY: superpathway of hexuroni...  0.000000
# VALSYN-PWY: L-valine biosynthesis                   0.000000
#
# [844 rows x 3 columns]

# %%
sorted_df['match_sign'] = (sorted_df['coef'] > 0) == (sorted_df['weight2'] > 0)
nonzero = sorted_df[sorted_df['abscoef'] > 0]
above_thresh = nonzero[nonzero['abscoef'] > 0.1]
above_thresh
# Out:
#                                                         coef   weight2  \
# feature
# s__Bifidobacterium_angulatum                        0.642635  0.213397
# s__Peptostreptococcus_stomatis                     -0.618613 -0.235289
# s__Solobacterium_moorei                            -0.614407 -0.364616
# s__Lactobacillus_acidophilus                        0.516800  0.049587
# s__Clostridium_bolteae                             -0.501387 -0.248070
# ...                                                      ...       ...
# PWY-6629: superpathway of L-tryptophan biosynth... -0.114855 -0.110203
# s__Acidaminococcus_fermentans                      -0.113528 -0.025354
# s__Bacteroides_clarus                               0.112191  0.016824
# s__Bifidobacterium_pseudocatenulatum                0.106847  0.001366
# PWY4LZ-257: superpathway of fermentation (Chlam...  0.104686  0.000182
#
#                                                      abscoef  match_sign
# feature
# s__Bifidobacterium_angulatum                        0.642635        True
# s__Peptostreptococcus_stomatis                      0.618613        True
# s__Solobacterium_moorei                             0.614407        True
# s__Lactobacillus_acidophilus                        0.516800        True
# s__Clostridium_bolteae                              0.501387        True
# ...                                                      ...         ...
# PWY-6629: superpathway of L-tryptophan biosynth...  0.114855        True
# s__Acidaminococcus_fermentans                       0.113528        True
# s__Bacteroides_clarus                               0.112191        True
# s__Bifidobacterium_pseudocatenulatum                0.106847        True
# PWY4LZ-257: superpathway of fermentation (Chlam...  0.104686        True
#
# [76 rows x 4 columns]

# %%
feature_list = list(above_thresh.index)
feature_list
# Out:
# ['s__Bifidobacterium_angulatum',
#  's__Peptostreptococcus_stomatis',
#  's__Solobacterium_moorei',
#  's__Lactobacillus_acidophilus',
#  's__Clostridium_bolteae',
#  'P164-PWY: purine nucleobases degradation I (anaerobic)',
#  's__Subdoligranulum_variabile',
#  'HISDEG-PWY: L-histidine degradation I',
#  'PWY66-389: phytol degradation',
#  's__Bifidobacterium_catenulatum',
#  'FUC-RHAMCAT-PWY: superpathway of fucose and rhamnose degradation',
#  's__Lactobacillus_mucosae',
#  's__Faecalibacterium_prausnitzii',
#  's__Holdemania_filiformis',
#  's__Ruminococcaceae_bacterium_D16',
#  's__Oxalobacter_formigenes',
#  's__Granulicatella_adiacens',
#  's__Bacteroides_caccae',
#  's__Streptococcus_gordonii',
#  's__Clostridium_methylpentosum',
#  's__Butyricimonas_synergistica',
#  's__Prevotella_timonensis',
#  's__Eubacterium_eligens',
#  's__Eubacterium_cylindroides',
#  's__Clostridium_celatum',
#  's__Actinomyces_odontolyticus',
#  's__Bacteroidales_bacterium_ph8',
#  's__Haemophilus_parainfluenzae',
#  's__Clostridium_bartlettii',
#  's__Lactobacillus_salivarius',
#  's__Sutterella_wadsworthensis',
#  's__Fusobacterium_varium',
#  's__Bacteroides_dorei',
#  's__Ruminococcus_callidus',
#  's__Clostridium_leptum',
#  's__Bifidobacterium_longum',
#  's__Peptoniphilus_lacrimalis',
#  's__Dialister_invisus',
#  'P124-PWY: Bifidobacterium shunt',
#  'P4-PWY: superpathway of L-lysine, L-threonine and L-methionine biosynthesis I',
#  's__Streptococcus_anginosus',
#  's__Alistipes_senegalensis',
#  'PWY-7371: 1,4-dihydroxy-6-naphthoate biosynthesis II',
#  's__Alistipes_finegoldii',
#  'NAGLIPASYN-PWY: lipid IVA biosynthesis',
#  's__Bacteroides_plebeius',
#  's__Clostridium_citroniae',
#  's__Streptococcus_thermophilus',
#  's__Fusobacterium_nucleatum',
#  's__Enterobacter_cloacae',
#  's__Streptococcus_vestibularis',
#  's__Bacteroides_coprocola',
#  's__Alistipes_sp_AP11',
#  's__Erysipelotrichaceae_bacterium_6_1_45',
#  'P163-PWY: L-lysine fermentation to acetate and butanoate',
#  's__Bacteroides_eggerthii',
#  's__Dorea_formicigenerans',
#  's__Phascolarctobacterium_succinatutens',
#  's__Lachnospiraceae_bacterium_3_1_57FAA_CT1',
#  's__Alistipes_shahii',
#  's__Atopobium_parvulum',
#  's__Haemophilus_pittmaniae',
#  'PWY-7391: isoprene biosynthesis II (engineered)',
#  's__Bilophila_wadsworthia',
#  's__Clostridium_perfringens',
#  's__Bacteroides_fragilis',
#  'METHGLYUT-PWY: superpathway of methylglyoxal degradation',
#  's__Coprococcus_comes',
#  's__Prevotella_copri',
#  'PWY-5941: glycogen degradation II (eukaryotic)',
#  's__Bifidobacterium_adolescentis',
#  'PWY-6629: superpathway of L-tryptophan biosynthesis',
#  's__Acidaminococcus_fermentans',
#  's__Bacteroides_clarus',
#  's__Bifidobacterium_pseudocatenulatum',
#  'PWY4LZ-257: superpathway of fermentation (Chlamydomonas reinhardtii)']

# %%
logreg = LogisticRegression(C=0.1, penalty='l1',
fit_intercept=False, max_iter=500, random_state=42,
                    solver='saga', n_jobs=-1)
clf = logreg.fit(X[feature_list], np.ravel(y))

# %%
coefficients = pd.DataFrame(feature_list, columns=['feature'])
coefficients['coef'] = clf.coef_[0]
coefficients.head()
# Out:
#                           feature      coef
# 0    s__Bifidobacterium_angulatum  0.628954
# 1  s__Peptostreptococcus_stomatis -0.644409
# 2         s__Solobacterium_moorei -0.616561
# 3    s__Lactobacillus_acidophilus  0.505078
# 4          s__Clostridium_bolteae -0.510624

# %%
coefficients.index = coefficients['feature']
del coefficients['feature']
coefficients['weight2'] = above_thresh['weight2']
coefficients
# Out:
#                                                         coef   weight2
# feature
# s__Bifidobacterium_angulatum                        0.628954  0.213397
# s__Peptostreptococcus_stomatis                     -0.644409 -0.235289
# s__Solobacterium_moorei                            -0.616561 -0.364616
# s__Lactobacillus_acidophilus                        0.505078  0.049587
# s__Clostridium_bolteae                             -0.510624 -0.248070
# ...                                                      ...       ...
# PWY-6629: superpathway of L-tryptophan biosynth... -0.056182 -0.110203
# s__Acidaminococcus_fermentans                      -0.200940 -0.025354
# s__Bacteroides_clarus                               0.120466  0.016824
# s__Bifidobacterium_pseudocatenulatum                0.171787  0.001366
# PWY4LZ-257: superpathway of fermentation (Chlam...  0.130384  0.000182
#
# [76 rows x 2 columns]

# %%
coefficients['match'] = (coefficients['coef'] > 0) == (coefficients['weight2'] > 0)
coefficients['match'].sum()
# Out:
# 65
